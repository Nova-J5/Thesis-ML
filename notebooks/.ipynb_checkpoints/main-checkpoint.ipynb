# %%
import pandas as pd

# Leggi il file XML e carica i dati in un DataFrame
#df = pd.read_xml("urine_metabolites.xml")
import json

import pandas as pd
import xmltodict
from flatten_json import flatten

#this will create a json object
data = json.loads(json.dumps(xmltodict.parse(xmltoparse)))

# this will put all items into a single row
dic_flattened = (flatten(d, '.') for d in [data])
df = pd.DataFrame(dic_flattened)
# Out:
#       version            creation_date              update_date    accession  \
# 0         5.0  2005-11-16 15:48:42 UTC  2021-10-13 17:34:04 UTC  HMDB0000001
# 1         5.0  2005-11-16 15:48:42 UTC  2021-10-13 04:18:52 UTC  HMDB0000002
# 2         5.0  2005-11-16 15:48:42 UTC  2020-11-09 23:11:34 UTC  HMDB0000005
# 3         5.0  2005-11-16 15:48:42 UTC  2021-09-14 15:44:51 UTC  HMDB0000008
# 4         5.0  2005-11-16 15:48:42 UTC  2021-09-14 15:41:25 UTC  HMDB0000010
# ...       ...                      ...                      ...          ...
# 4687      5.0  2020-11-01 18:42:26 UTC  2021-09-14 15:45:32 UTC  HMDB0240733
# 4688      5.0  2020-11-01 18:42:31 UTC  2021-09-14 15:15:57 UTC  HMDB0240734
# 4689      5.0  2020-11-01 18:42:36 UTC  2021-09-14 15:48:00 UTC  HMDB0240735
# 4690      5.0  2020-11-01 18:42:41 UTC  2021-09-14 14:59:16 UTC  HMDB0240736
# 4691      5.0  2020-11-01 18:42:47 UTC  2021-09-14 14:57:34 UTC  HMDB0240737
#
#           status  secondary_accessions  \
# 0     quantified                   NaN
# 1     quantified                   NaN
# 2     quantified                   NaN
# 3     quantified                   NaN
# 4     quantified                   NaN
# ...          ...                   ...
# 4687    detected                   NaN
# 4688    detected                   NaN
# 4689    detected                   NaN
# 4690    detected                   NaN
# 4691    detected                   NaN
#
#                                         name  \
# 0                          1-Methylhistidine
# 1                         1,3-Diaminopropane
# 2                         2-Ketobutyric acid
# 3                      2-Hydroxybutyric acid
# 4                           2-Methoxyestrone
# ...                                      ...
# 4687                   Epinephrine 3-sulfate
# 4688     Taurodeoxycholic acid 3-glucuronide
# 4689            Isolariciresinol glucuronide
# 4690  Dodecanoyl-sn-glycero-3-phosphocholine
# 4691       Hydroxymatairesinol glucuronide 1
#
#                                             description  synonyms  \
# 0     1-Methylhistidine, also known as 1-MHis or 1MH...       NaN
# 1     1,3-Diaminopropane, also known as DAP or trime...       NaN
# 2     2-Ketobutyric acid, also known as alpha-ketobu...       NaN
# 3     2-Hydroxybutyric acid (CAS: 600-15-7), also kn...       NaN
# 4     2-Methoxyestrone (or 2-ME1) belongs to the cla...       NaN
# ...                                                 ...       ...
# 4687                                               None       NaN
# 4688                                               None       NaN
# 4689                                               None       NaN
# 4690                                               None       NaN
# 4691                                               None       NaN
#
#      chemical_formula  ...  kegg_id       biocyc_id  bigg_id  \
# 0           C7H11N3O2  ...   C01152            None      NaN
# 1             C3H10N2  ...   C00986         CPD-313      NaN
# 2              C4H6O3  ...   C00109  2-OXOBUTANOATE  33889.0
# 3              C4H8O3  ...   C05984        CPD-3564      NaN
# 4            C19H24O3  ...   C05299            None      NaN
# ...               ...  ...      ...             ...      ...
# 4687        C9H13NO6S  ...     None            None      NaN
# 4688      C32H53NO12S  ...     None            None      NaN
# 4689        C26H32O12  ...     None            None      NaN
# 4690       C20H42NO7P  ...     None            None      NaN
# 4691        C26H30O13  ...     None            None      NaN
#
#                 wikipedia_id metlin_id  vmh_id fbonto_id  \
# 0            Methylhistidine    3741.0    None       NaN
# 1         1,3-Diaminopropane       NaN    None       NaN
# 2     Alpha-Ketobutyric_acid       NaN   2OBUT       NaN
# 3      2-Hydroxybutyric_acid       NaN    None       NaN
# 4           2-Methoxyestrone    2578.0  C05299       NaN
# ...                      ...       ...     ...       ...
# 4687                    None       NaN    None       NaN
# 4688                    None       NaN    None       NaN
# 4689                    None       NaN    None       NaN
# 4690                    None       NaN    None       NaN
# 4691                    None       NaN    None       NaN
#
#                                     synthesis_reference  general_references  \
# 0     Jain, Rahul; Cohen, Louis A. Regiospecific alk...                 NaN
# 1     Takayanagi, Yasuyuki; Oohinata, Takahiro.  Pre...                 NaN
# 2     Figge, Rainer; Lux, Fabien; Raynaud, Celine; S...                 NaN
# 3     Carlier, J. P.; Henry, C.; Lorin, V.; Rouffign...                 NaN
# 4     Stoelwinder, Johannes; Moers, Nicolaas Elisabe...                 NaN
# ...                                                 ...                 ...
# 4687                                               None                 NaN
# 4688                                               None                 NaN
# 4689                                               None                 NaN
# 4690                                               None                 NaN
# 4691                                               None                 NaN
#
#       protein_associations
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 4687                   NaN
# 4688                   NaN
# 4689                   NaN
# 4690                   NaN
# 4691                   NaN
#
# [4692 rows x 46 columns]
